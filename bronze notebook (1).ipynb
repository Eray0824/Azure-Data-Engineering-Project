# %%
# Mount ADLS Gen2
# Required each time the cluster is restarted which should be only on the first notebook as they run in order

tiers = ["bronze", "silver", "gold"]
adls_paths = {tier: f"abfss://{tier}@dataquake24.dfs.core.windows.net/" for tier in tiers}

# Accessing paths
bronze_adls = adls_paths["bronze"]
silver_adls = adls_paths["silver"]
gold_adls = adls_paths["gold"] 

dbutils.fs.ls(bronze_adls)
dbutils.fs.ls(silver_adls)
dbutils.fs.ls(gold_adls)
# Out:
# [FileInfo(path='abfss://gold@dataquake24.dfs.core.windows.net/earthquake_events_gold/', name='earthquake_events_gold/', size=0, modificationTime=1750112844000)]

# %%
import requests
import json
from datetime import date, timedelta

# %%
# For Data Factory -Get base parameters
dbutils.widgets.text("start_date", "")
dbutils.widgets.text("end_date", "")
start_date = dbutils.widgets.get("start_date")
end_date = dbutils.widgets.get("end_date")

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the ADLS path
        file_path = f"{bronze_adls}/{start_date}_earthquake_data.json"

        # Save the JSON data
        json_data = json.dumps(data, indent=4)
        dbutils.fs.put(file_path, json_data, overwrite=True)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# Wrote 11826914 bytes.
# Data successfully saved to abfss://bronze@dataquake24.dfs.core.windows.net//_earthquake_data.json

# %%
# data
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '44 km NW of Toyah, Texas',
#    'time': 1750156890491,
#    'updated': 1750157216900,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvjnua',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvjnua&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'tx',
#    'code': '2025lvjnua',
#    'ids': ',tx2025lvjnua,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 31,
#    'dmin': 0,
#    'rms': 0.4,
#    'gap': 56,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 44 km NW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.111, 31.614, 4.7899]},
#   'id': 'tx2025lvjnua'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.22,
#    'place': '7 km WNW of Cobb, CA',
#    'time': 1750156724490,
#    'updated': 1750156819340,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196756',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196756&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '75196756',
#    'ids': ',nc75196756,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.00839,
#    'rms': 0.01,
#    'gap': 97,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 7 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.800498962402, 38.8356666564941, 2.28999996185303]},
#   'id': 'nc75196756'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.4,
#    'place': '6 km WSW of Anza, CA',
#    'time': 1750156322820,
#    'updated': 1750156532705,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996575',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996575&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '40996575',
#    'ids': ',ci40996575,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 21,
#    'dmin': 0.03349,
#    'rms': 0.12,
#    'gap': 40,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 6 km WSW of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7283333, 33.5326667, 5.44]},
#   'id': 'ci40996575'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.91,
#    'place': '2 km NNE of The Geysers, CA',
#    'time': 1750156020720,
#    'updated': 1750156119011,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196751',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196751&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 13,
#    'net': 'nc',
#    'code': '75196751',
#    'ids': ',nc75196751,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.006306,
#    'rms': 0.02,
#    'gap': 142,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 2 km NNE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.753997802734, 38.7961654663086, 0.689999997615814]},
#   'id': 'nc75196751'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.86,
#    'place': '6 km SSW of Redlands, CA',
#    'time': 1750155870010,
#    'updated': 1750156076673,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996567',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996567&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'ci',
#    'code': '40996567',
#    'ids': ',ci40996567,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 38,
#    'dmin': 0.1061,
#    'rms': 0.18,
#    'gap': 66,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 6 km SSW of Redlands, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.2076667, 34.0106667, 13.71]},
#   'id': 'ci40996567'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.05,
#    'place': '4 km SSE of Maria Antonia, Puerto Rico',
#    'time': 1750155654730,
#    'updated': 1750156676280,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71486008',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71486008&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'pr',
#    'code': '71486008',
#    'ids': ',pr71486008,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.03485,
#    'rms': 0.17,
#    'gap': 219,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 4 km SSE of Maria Antonia, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.8716666666667, 17.9375, 13.56]},
#   'id': 'pr71486008'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.67,
#    'place': '9 km SW of Idyllwild, CA',
#    'time': 1750154145970,
#    'updated': 1750154349923,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996559',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996559&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'ci',
#    'code': '40996559',
#    'ids': ',ci40996559,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 32,
#    'dmin': 0.06879,
#    'rms': 0.15,
#    'gap': 76,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 9 km SW of Idyllwild, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7813333, 33.6768333, 10.23]},
#   'id': 'ci40996559'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.23,
#    'place': '2 km NW of Frazier Park, CA',
#    'time': 1750152845170,
#    'updated': 1750153047658,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996551',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996551&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '40996551',
#    'ids': ',ci40996551,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 26,
#    'dmin': 0.06124,
#    'rms': 0.21,
#    'gap': 66,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 2 km NW of Frazier Park, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.9566667, 34.8356667, 10.48]},
#   'id': 'ci40996551'},
#  {'type': 'Feature',
#   'properties': {'mag': 1,
#    'place': '5 km E of Big Lake, Alaska',
#    'time': 1750152794844,
#    'updated': 1750152914886,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pzub6k',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pzub6k&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'ak',
#    'code': '0257pzub6k',
#    'ids': ',ak0257pzub6k,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.12,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 5 km E of Big Lake, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.853, 61.5213, 42.4]},
#   'id': 'ak0257pzub6k'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '15 km ESE of Livengood, Alaska',
#    'time': 1750152702815,
#    'updated': 1750152812102,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pztxwp',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pztxwp&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ak',
#    'code': '0257pztxwp',
#    'ids': ',ak0257pztxwp,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 1.05,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 15 km ESE of Livengood, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.2354, 65.476, 8.2]},
#   'id': 'ak0257pztxwp'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '6 km ENE of Coleville, California',
#    'time': 1750152464070,
#    'updated': 1750152624927,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00899045',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00899045&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'nn',
#    'code': '00899045',
#    'ids': ',nn00899045,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.242,
#    'rms': 0.1282,
#    'gap': 83.80000000000001,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 6 km ENE of Coleville, California'},
#   'geometry': {'type': 'Point', 'coordinates': [-119.4363, 38.5911, 4.1]},
#   'id': 'nn00899045'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.8,
#    'place': '196 km S of ‘Ohonua, Tonga',
#    'time': 1750151790483,
#    'updated': 1750156997040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qksf',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qksf&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 354,
#    'net': 'us',
#    'code': '6000qksf',
#    'ids': ',us6000qksf,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 6.151,
#    'rms': 0.48,
#    'gap': 111,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.8 - 196 km S of ‘Ohonua, Tonga'},
#   'geometry': {'type': 'Point', 'coordinates': [-174.9129, -23.1181, 10]},
#   'id': 'us6000qksf'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.2,
#    'place': '47 km NNW of Carlin, Nevada',
#    'time': 1750151393314,
#    'updated': 1750154035755,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00899041',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00899041&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 158,
#    'net': 'nn',
#    'code': '00899041',
#    'ids': ',nn00899041,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.137,
#    'rms': 0.114,
#    'gap': 63.94999999999999,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 47 km NNW of Carlin, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2924, 41.1143, 1.7]},
#   'id': 'nn00899041'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.2,
#    'place': '10 km E of Pāhala, Hawaii',
#    'time': 1750151269710,
#    'updated': 1750151502400,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74700582',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74700582&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 74,
#    'net': 'hv',
#    'code': '74700582',
#    'ids': ',hv74700582,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 59,
#    'dmin': 0.04204,
#    'rms': 0.129999995,
#    'gap': 163,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 10 km E of Pāhala, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.376327514648, 19.2003326416016, 31.0400009155273]},
#   'id': 'hv74700582'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '32 km WNW of Rachel, Nevada',
#    'time': 1750151122562,
#    'updated': 1750151272735,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00899039',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00899039&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'nn',
#    'code': '00899039',
#    'ids': ',nn00899039,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.691,
#    'rms': 0.3883,
#    'gap': 225.95,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 32 km WNW of Rachel, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.0755, 37.7628, 4.8]},
#   'id': 'nn00899039'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.51,
#    'place': '27 km W of Olancha, CA',
#    'time': 1750150832280,
#    'updated': 1750151051954,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996543',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996543&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ci',
#    'code': '40996543',
#    'ids': ',ci40996543,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 24,
#    'dmin': 0.09686,
#    'rms': 0.23,
#    'gap': 96,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 27 km W of Olancha, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-118.3015, 36.2486667, 4.64]},
#   'id': 'ci40996543'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.75,
#    'place': '3 km NW of Palomar Observatory, CA',
#    'time': 1750150655150,
#    'updated': 1750150955259,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996535',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996535&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'ci',
#    'code': '40996535',
#    'ids': ',ci40996535,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 39,
#    'dmin': 0.02819,
#    'rms': 0.22,
#    'gap': 31,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 3 km NW of Palomar Observatory, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.8871667, 33.373, 5.8]},
#   'id': 'ci40996535'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '66 km SE of Denali National Park, Alaska',
#    'time': 1750150569038,
#    'updated': 1750150692323,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pzdslj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pzdslj&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0257pzdslj',
#    'ids': ',ak0257pzdslj,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.25,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 66 km SE of Denali National Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.7047, 63.1527, 104.5]},
#   'id': 'ak0257pzdslj'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '13 km NNE of Lamesa, Texas',
#    'time': 1750150038939,
#    'updated': 1750150215672,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvftjr',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvftjr&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'tx',
#    'code': '2025lvftjr',
#    'ids': ',tx2025lvftjr,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.2,
#    'rms': 0.6,
#    'gap': 235,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 13 km NNE of Lamesa, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.878, 32.845, 5]},
#   'id': 'tx2025lvftjr'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.93,
#    'place': '27 km SE of Bodie, CA',
#    'time': 1750149641280,
#    'updated': 1750153266390,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196741',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196741&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 132,
#    'net': 'nc',
#    'code': '75196741',
#    'ids': ',nc75196741,nn00899032,',
#    'sources': ',nc,nn,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 39,
#    'dmin': 0.2282,
#    'rms': 0.05,
#    'gap': 67,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 27 km SE of Bodie, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.785333333333, 38.0463333333333, 10.4]},
#   'id': 'nc75196741'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.06,
#    'place': '14 km W of Round Valley, CA',
#    'time': 1750149626620,
#    'updated': 1750153418470,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196736',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196736&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'nc',
#    'code': '75196736',
#    'ids': ',nc75196736,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.197,
#    'rms': 0.08,
#    'gap': 80,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 14 km W of Round Valley, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.7515, 37.3771666666667, 11.4]},
#   'id': 'nc75196736'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.22,
#    'place': '11 km NNW of Warner Springs, CA',
#    'time': 1750149484360,
#    'updated': 1750149610685,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996519',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996519&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '40996519',
#    'ids': ',ci40996519,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 17,
#    'dmin': 0.1441,
#    'rms': 0.16,
#    'gap': 121,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 11 km NNW of Warner Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.690834, 33.3708344, 9.86]},
#   'id': 'ci40996519'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.3,
#    'place': '42 km ENE of Barcelona, Philippines',
#    'time': 1750149382986,
#    'updated': 1750151757233,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qks2',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qks2&format=geojson',
#    'felt': 1,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 432,
#    'net': 'us',
#    'code': '6000qks2',
#    'ids': ',us6000qks2,usauto6000qks2,',
#    'sources': ',us,usauto,',
#    'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#    'nst': 100,
#    'dmin': 1.706,
#    'rms': 1.23,
#    'gap': 67,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.3 - 42 km ENE of Barcelona, Philippines'},
#   'geometry': {'type': 'Point', 'coordinates': [126.8035, 8.2769, 34.84]},
#   'id': 'us6000qks2'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '62 km ESE of Denali Park, Alaska',
#    'time': 1750148857782,
#    'updated': 1750148997254,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pz7n1u',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pz7n1u&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0257pz7n1u',
#    'ids': ',ak0257pz7n1u,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.61,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 62 km ESE of Denali Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.7111, 63.5738, 0]},
#   'id': 'ak0257pz7n1u'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': '44 km E of Severo-Kuril’sk, Russia',
#    'time': 1750147999239,
#    'updated': 1750149616040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qkrz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qkrz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '6000qkrz',
#    'ids': ',us6000qkrz,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 55,
#    'dmin': 2.526,
#    'rms': 0.64,
#    'gap': 152,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - 44 km E of Severo-Kuril’sk, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [156.7597, 50.6542, 91.831]},
#   'id': 'us6000qkrz'},
#  {'type': 'Feature',
#   'properties': {'mag': 5,
#    'place': 'southern Mid-Atlantic Ridge',
#    'time': 1750147975629,
#    'updated': 1750149275040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qks0',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qks0&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 385,
#    'net': 'us',
#    'code': '6000qks0',
#    'ids': ',us6000qks0,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 44,
#    'dmin': 4.254,
#    'rms': 0.91,
#    'gap': 59,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.0 - southern Mid-Atlantic Ridge'},
#   'geometry': {'type': 'Point', 'coordinates': [-13.2948, -32.8812, 10]},
#   'id': 'us6000qks0'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.79,
#    'place': '10 km ESE of Alder Springs, CA',
#    'time': 1750147961360,
#    'updated': 1750150239995,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196731',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196731&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 49,
#    'net': 'nc',
#    'code': '75196731',
#    'ids': ',nc75196731,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.08091,
#    'rms': 0.11,
#    'gap': 42,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 10 km ESE of Alder Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.611333333333, 39.65, 15.27]},
#   'id': 'nc75196731'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.77,
#    'place': '16 km W of Johannesburg, CA',
#    'time': 1750147562680,
#    'updated': 1750147773090,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996511',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996511&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'ci',
#    'code': '40996511',
#    'ids': ',ci40996511,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.09299,
#    'rms': 0.15,
#    'gap': 74,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 16 km W of Johannesburg, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.8058333, 35.3546667, 8.26]},
#   'id': 'ci40996511'},
#  {'type': 'Feature',
#   'properties': {'mag': 1,
#    'place': '7 km ESE of Truckee, California',
#    'time': 1750147196497,
#    'updated': 1750147312736,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00899031',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00899031&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'nn',
#    'code': '00899031',
#    'ids': ',nn00899031,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.048,
#    'rms': 0.0934,
#    'gap': 91.80000000000001,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 7 km ESE of Truckee, California'},
#   'geometry': {'type': 'Point', 'coordinates': [-120.0966, 39.3059, 7.9]},
#   'id': 'nn00899031'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '26 km W of Anchor Point, Alaska',
#    'time': 1750147130505,
#    'updated': 1750147273001,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pysvly',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pysvly&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0257pysvly',
#    'ids': ',ak0257pysvly,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.14,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 26 km W of Anchor Point, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.288, 59.738, 74.3]},
#   'id': 'ak0257pysvly'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.55,
#    'place': '1 km NE of The Geysers, CA',
#    'time': 1750146293500,
#    'updated': 1750146388930,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196726',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196726&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 37,
#    'net': 'nc',
#    'code': '75196726',
#    'ids': ',nc75196726,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 25,
#    'dmin': 0.02173,
#    'rms': 0.04,
#    'gap': 82,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 1 km NE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.746170043945, 38.7861671447754, 1.99000000953674]},
#   'id': 'nc75196726'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.39,
#    'place': '1 km NNW of The Geysers, CA',
#    'time': 1750145998700,
#    'updated': 1750148853147,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196721',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196721&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'nc',
#    'code': '75196721',
#    'ids': ',nc75196721,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 17,
#    'dmin': 0.01325,
#    'rms': 0.04,
#    'gap': 85,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 1 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.763333333333, 38.7876666666667, 0.92]},
#   'id': 'nc75196721'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '55 km NW of Toyah, Texas',
#    'time': 1750145772932,
#    'updated': 1750147330955,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvdiga',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvdiga&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'tx',
#    'code': '2025lvdiga',
#    'ids': ',tx2025lvdiga,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 35,
#    'dmin': 0.1,
#    'rms': 0.3,
#    'gap': 62,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 55 km NW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.202, 31.668, 4.5057]},
#   'id': 'tx2025lvdiga'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '56 km S of Whites City, New Mexico',
#    'time': 1750143427797,
#    'updated': 1750143658714,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvccjz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvccjz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'tx',
#    'code': '2025lvccjz',
#    'ids': ',tx2025lvccjz,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 31,
#    'dmin': 0,
#    'rms': 0.6,
#    'gap': 69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 56 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.378, 31.666, 5.438]},
#   'id': 'tx2025lvccjz'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.13,
#    'place': '2 km ESE of Lake Henshaw, CA',
#    'time': 1750143172380,
#    'updated': 1750143414398,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996495',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996495&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 20,
#    'net': 'ci',
#    'code': '40996495',
#    'ids': ',ci40996495,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 30,
#    'dmin': 0.1562,
#    'rms': 0.15,
#    'gap': 203,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 2 km ESE of Lake Henshaw, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.744, 33.2328333, 9.88]},
#   'id': 'ci40996495'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.73,
#    'place': '2 km ESE of Lake Henshaw, CA',
#    'time': 1750143172320,
#    'updated': 1750143382300,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996487',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996487&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'ci',
#    'code': '40996487',
#    'ids': ',ci40996487,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 55,
#    'dmin': 0.01665,
#    'rms': 0.17,
#    'gap': 34,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 2 km ESE of Lake Henshaw, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.74, 33.2305, 10.79]},
#   'id': 'ci40996487'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.53,
#    'place': '5 km W of The Geysers, CA',
#    'time': 1750143148050,
#    'updated': 1750151355917,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196711',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196711&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 4,
#    'net': 'nc',
#    'code': '75196711',
#    'ids': ',nc75196711,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 28,
#    'dmin': 0.02065,
#    'rms': 0.04,
#    'gap': 128,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.5 - 5 km W of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.809833333333, 38.7683333333333, 2.23]},
#   'id': 'nc75196711'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '56 km S of Whites City, New Mexico',
#    'time': 1750142949611,
#    'updated': 1750157465016,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvbvoe',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvbvoe&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'tx',
#    'code': '2025lvbvoe',
#    'ids': ',us6000qkrs,tx2025lvbvoe,',
#    'sources': ',us,tx,',
#    'types': ',origin,phase-data,',
#    'nst': 42,
#    'dmin': 0,
#    'rms': 0.3,
#    'gap': 70,
#    'magType': 'mlv',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 56 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.375, 31.663, 4.3604]},
#   'id': 'tx2025lvbvoe'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.2,
#    'place': '35 km W of Archidona, Ecuador',
#    'time': 1750142835582,
#    'updated': 1750143946040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qkrr',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qkrr&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 271,
#    'net': 'us',
#    'code': '6000qkrr',
#    'ids': ',us6000qkrr,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.282,
#    'rms': 0.6,
#    'gap': 87,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.2 - 35 km W of Archidona, Ecuador'},
#   'geometry': {'type': 'Point', 'coordinates': [-78.1261, -0.9027, 6.565]},
#   'id': 'us6000qkrr'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.52,
#    'place': '15 km SSE of Big Bear Lake, CA',
#    'time': 1750142049800,
#    'updated': 1750142291098,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996479',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996479&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 4,
#    'net': 'ci',
#    'code': '40996479',
#    'ids': ',ci40996479,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.06121,
#    'rms': 0.13,
#    'gap': 89,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.5 - 15 km SSE of Big Bear Lake, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.8663333, 34.114, 2.65]},
#   'id': 'ci40996479'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.36,
#    'place': '15 km W of Johannesburg, CA',
#    'time': 1750141557030,
#    'updated': 1750141768059,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996471',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996471&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'ci',
#    'code': '40996471',
#    'ids': ',ci40996471,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 36,
#    'dmin': 0.09705,
#    'rms': 0.15,
#    'gap': 73,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 15 km W of Johannesburg, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.8041667, 35.3585, 6.91]},
#   'id': 'ci40996471'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.1,
#    'place': '168 km WNW of Tobelo, Indonesia',
#    'time': 1750141533587,
#    'updated': 1750142686040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qkrl',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qkrl&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 400,
#    'net': 'us',
#    'code': '6000qkrl',
#    'ids': ',us6000qkrl,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 103,
#    'dmin': 1.621,
#    'rms': 1.22,
#    'gap': 44,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.1 - 168 km WNW of Tobelo, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [126.5703, 2.1928, 51.95]},
#   'id': 'us6000qkrl'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '49 km N of Chase, Alaska',
#    'time': 1750140752159,
#    'updated': 1750143104431,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pxxjnz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pxxjnz&format=geojson',
#    'felt': 1,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 45,
#    'net': 'ak',
#    'code': '0257pxxjnz',
#    'ids': ',ak0257pxxjnz,',
#    'sources': ',ak,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.38,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 49 km N of Chase, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.1062, 62.8914, 65.9]},
#   'id': 'ak0257pxxjnz'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '18 km NW of Midland, Texas',
#    'time': 1750140219080,
#    'updated': 1750143671548,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvaidx',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvaidx&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'tx',
#    'code': '2025lvaidx',
#    'ids': ',tx2025lvaidx,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 25,
#    'dmin': 0,
#    'rms': 0.5,
#    'gap': 75,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 18 km NW of Midland, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-102.204, 32.125, 4.4183]},
#   'id': 'tx2025lvaidx'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '18 km NW of Midland, Texas',
#    'time': 1750140069124,
#    'updated': 1750140367880,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025lvagfd',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025lvagfd&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'tx',
#    'code': '2025lvagfd',
#    'ids': ',tx2025lvagfd,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 46,
#    'dmin': 0,
#    'rms': 0.5,
#    'gap': 84,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 18 km NW of Midland, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-102.203, 32.128, 4.8168]},
#   'id': 'tx2025lvagfd'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.3,
#    'place': '34 km E of Noatak, Alaska',
#    'time': 1750139956758,
#    'updated': 1750141188040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257pxm5hy',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257pxm5hy&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 168,
#    'net': 'ak',
#    'code': '0257pxm5hy',
#    'ids': ',us6000qkrg,ak0257pxm5hy,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.93,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 34 km E of Noatak, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-162.1536, 67.5651, 31]},
#   'id': 'ak0257pxm5hy'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.94,
#    'place': '9 km ENE of Borrego Springs, CA',
#    'time': 1750138877370,
#    'updated': 1750139091589,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996463',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996463&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'ci',
#    'code': '40996463',
#    'ids': ',ci40996463,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 42,
#    'dmin': 0.08125,
#    'rms': 0.23,
#    'gap': 39,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 9 km ENE of Borrego Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.2798333, 33.2848333, 5.26]},
#   'id': 'ci40996463'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.94,
#    'place': '15 km ESE of Ocotillo, CA',
#    'time': 1750138571100,
#    'updated': 1750139233200,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996455',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996455&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 58,
#    'net': 'ci',
#    'code': '40996455',
#    'ids': ',ci40996455,',
#    'sources': ',ci,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 46,
#    'dmin': 0.06247,
#    'rms': 0.26,
#    'gap': 74,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 15 km ESE of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.853, 32.6696667, 8.03]},
#   'id': 'ci40996455'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.29,
#    'place': '3 km ENE of Healdsburg, CA',
#    'time': 1750138439820,
#    'updated': 1750151898997,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196706',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196706&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nc',
#    'code': '75196706',
#    'ids': ',nc75196706,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 48,
#    'dmin': 0.02682,
#    'rms': 0.07,
#    'gap': 52,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 3 km ENE of Healdsburg, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.842333333333, 38.6291666666667, 3.05]},
#   'id': 'nc75196706'},
#  {'type': 'Feature',
#   'properties': {'mag': 2,
#    'place': '50 km W of Mentone, Texas',
#    'time': 1750137942723,
#    'updated': 1750157454017,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025luzbpl',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025luzbpl&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 62,
#    'net': 'tx',
#    'code': '2025luzbpl',
#    'ids': ',tx2025luzbpl,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 41,
#    'dmin': 0.1,
#    'rms': 0.4,
#    'gap': 43,
#    'magType': 'mlv',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 50 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.135, 31.698, 3.6977]},
#   'id': 'tx2025luzbpl'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.94,
#    'place': '9 km SSW of Idyllwild, CA',
#    'time': 1750137725030,
#    'updated': 1750137988810,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996447',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996447&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'ci',
#    'code': '40996447',
#    'ids': ',ci40996447,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.06447,
#    'rms': 0.12,
#    'gap': 67,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 9 km SSW of Idyllwild, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.759, 33.6628333, 14.49]},
#   'id': 'ci40996447'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.35,
#    'place': '6 km WSW of Anza, CA',
#    'time': 1750137707790,
#    'updated': 1750137913803,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996439',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996439&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '40996439',
#    'ids': ',ci40996439,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 17,
#    'dmin': 0.03553,
#    'rms': 0.17,
#    'gap': 40,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 6 km WSW of Anza, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.731, 33.5301667, 5.4]},
#   'id': 'ci40996439'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.85,
#    'place': '4 km NE of Ocotillo Wells, CA',
#    'time': 1750136331320,
#    'updated': 1750136540337,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996415',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996415&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'ci',
#    'code': '40996415',
#    'ids': ',ci40996415,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 46,
#    'dmin': 0.05394,
#    'rms': 0.19,
#    'gap': 41,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 4 km NE of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.1053333, 33.1681667, 10.08]},
#   'id': 'ci40996415'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.07,
#    'place': '4 km W of Cobb, CA',
#    'time': 1750136259840,
#    'updated': 1750136356337,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196696',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196696&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'nc',
#    'code': '75196696',
#    'ids': ',nc75196696,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.01293,
#    'rms': 0.01,
#    'gap': 107,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 4 km W of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.764663696289, 38.8165016174316, 1.71000003814697]},
#   'id': 'nc75196696'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.91,
#    'place': '3 km ESE of Lake Henshaw, CA',
#    'time': 1750135714650,
#    'updated': 1750135999429,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40996399',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40996399&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 13,
#    'net': 'ci',
#    'code': '40996399',
#    'ids': ',ci40996399,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 39,
#    'dmin': 0.01948,
#    'rms': 0.16,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 3 km ESE of Lake Henshaw, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7368333, 33.2295, 11.32]},
#   'id': 'ci40996399'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.52,
#    'place': '4 km W of Cobb, CA',
#    'time': 1750135653470,
#    'updated': 1750135840850,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75196686',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75196686&format=geojson',
# ...
#    'nst': 6,
#    'dmin': 0.002546,
#    'rms': 0.27,
#    'gap': 89,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -1.0 - 60 km SE of Pedro Bay, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-153.449666666667, 59.3625, -1.07]},
#   'id': 'av93044564'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.24,
#    'place': '7 km NW of The Geysers, CA',
#    'time': 1749836886230,
#    'updated': 1750113096890,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75003723',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75003723&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'nc',
#    'code': '75003723',
#    'ids': ',nc75003723,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 33,
#    'dmin': 0.004499,
#    'rms': 0.04,
#    'gap': 40,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 7 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.815833333333, 38.8233333333333, 1.08]},
#   'id': 'nc75003723'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.27,
#    'place': '22 km ENE of San Lucas, CA',
#    'time': 1749836840240,
#    'updated': 1750113309130,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75195196',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75195196&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 79,
#    'net': 'nc',
#    'code': '75195196',
#    'ids': ',nc75195196,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 72,
#    'dmin': 0.1354,
#    'rms': 0.18,
#    'gap': 51,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 22 km ENE of San Lucas, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-120.818833333333, 36.2373333333333, 9.2]},
#   'id': 'nc75195196'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '28 km SSE of Funny River, Alaska',
#    'time': 1749836787103,
#    'updated': 1749937227040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257jij7au',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257jij7au&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'ak',
#    'code': '0257jij7au',
#    'ids': ',ak0257jij7au,us6000qk4m,',
#    'sources': ',ak,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.44,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 28 km SSE of Funny River, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.5983, 60.2562, 39.7]},
#   'id': 'ak0257jij7au'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '3 km NNE of Ridgeway, Alaska',
#    'time': 1749836713301,
#    'updated': 1749836833269,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257jiiyiq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257jiiyiq&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0257jiiyiq',
#    'ids': ',ak0257jiiyiq,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.31,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 3 km NNE of Ridgeway, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.065, 60.5625, 17.1]},
#   'id': 'ak0257jiiyiq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.84,
#    'place': '15 km ESE of Little Lake, CA',
#    'time': 1749836319310,
#    'updated': 1749847467870,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40993375',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40993375&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 52,
#    'net': 'ci',
#    'code': '40993375',
#    'ids': ',ci40993375,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.07467,
#    'rms': 0.15,
#    'gap': 38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 15 km ESE of Little Lake, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.7455, 35.903, 7.22]},
#   'id': 'ci40993375'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.02,
#    'place': '7 km ESE of Dougherty, Oklahoma',
#    'time': 1749836190350,
#    'updated': 1750083330330,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2025lndw',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2025lndw&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 16,
#    'net': 'ok',
#    'code': '2025lndw',
#    'ids': ',ok2025lndw,',
#    'sources': ',ok,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.3653283101,
#    'rms': 0.25,
#    'gap': 125,
#    'magType': 'ml',
#    'type': 'quarry blast',
#    'title': 'M 1.0 Quarry Blast - 7 km ESE of Dougherty, Oklahoma'},
#   'geometry': {'type': 'Point', 'coordinates': [-96.977, 34.371, 0]},
#   'id': 'ok2025lndw'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.18,
#    'place': '16 km SSE of Guánica, Puerto Rico',
#    'time': 1749836143660,
#    'updated': 1749836586030,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71485738',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71485738&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 73,
#    'net': 'pr',
#    'code': '71485738',
#    'ids': ',pr71485738,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.147,
#    'rms': 0.08,
#    'gap': 296,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 16 km SSE of Guánica, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.8521666666667, 17.8295, 7.87]},
#   'id': 'pr71485738'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '16 km WSW of Denali Park, Alaska',
#    'time': 1749835789620,
#    'updated': 1749835933395,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257jiflv6',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257jiflv6&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0257jiflv6',
#    'ids': ',ak0257jiflv6,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.69,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 16 km WSW of Denali Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.2441, 63.6985, 0]},
#   'id': 'ak0257jiflv6'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.65,
#    'place': '10 km WSW of Falls City, Oregon',
#    'time': 1749835787740,
#    'updated': 1749886761210,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62127941',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62127941&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 6,
#    'net': 'uw',
#    'code': '62127941',
#    'ids': ',uw62127941,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.1012,
#    'rms': 0.13,
#    'gap': 159,
#    'magType': 'md',
#    'type': 'explosion',
#    'title': 'M 0.7 Explosion - 10 km WSW of Falls City, Oregon'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.57033333333334, 44.84583333333333, -0.39]},
#   'id': 'uw62127941'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.72,
#    'place': '9 km SSE of Guánica, Puerto Rico',
#    'time': 1749835758680,
#    'updated': 1749836234780,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71485733',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71485733&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 46,
#    'net': 'pr',
#    'code': '71485733',
#    'ids': ',pr71485733,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.079,
#    'rms': 0.14,
#    'gap': 237,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 9 km SSE of Guánica, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.8711666666667, 17.896, 9.63]},
#   'id': 'pr71485733'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.12,
#    'place': '5 km SW of Guánica, Puerto Rico',
#    'time': 1749835579190,
#    'updated': 1749836175020,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71485723',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71485723&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 69,
#    'net': 'pr',
#    'code': '71485723',
#    'ids': ',pr71485723,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.0708,
#    'rms': 0.07,
#    'gap': 218,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 5 km SW of Guánica, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.9416666666667, 17.9363333333333, 9.97]},
#   'id': 'pr71485723'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.67,
#    'place': '20 km SSE of Carmel Valley Village, CA',
#    'time': 1749835125140,
#    'updated': 1749839591880,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75195186',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75195186&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'nc',
#    'code': '75195186',
#    'ids': ',nc75195186,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.0604,
#    'rms': 0.08,
#    'gap': 78,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 20 km SSE of Carmel Valley Village, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.632666666667, 36.367, 6.35]},
#   'id': 'nc75195186'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.59,
#    'place': '15 km ESE of Little Lake, CA',
#    'time': 1749835083640,
#    'updated': 1749847446696,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40993359',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40993359&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ci',
#    'code': '40993359',
#    'ids': ',ci40993359,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 31,
#    'dmin': 0.07414,
#    'rms': 0.15,
#    'gap': 38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 15 km ESE of Little Lake, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.7465, 35.9028333, 7.11]},
#   'id': 'ci40993359'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.2,
#    'place': '88 km NNW of Karluk, Alaska',
#    'time': 1749834735370,
#    'updated': 1749865835860,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93044559',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93044559&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'av',
#    'code': '93044559',
#    'ids': ',av93044559,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.01765,
#    'rms': 0.12,
#    'gap': 162,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -0.2 - 88 km NNW of Karluk, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.092833333333, 58.2881666666667, 5.7]},
#   'id': 'av93044559'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.87,
#    'place': '10 km W of Aguanga, CA',
#    'time': 1749834665100,
#    'updated': 1749847449697,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40993351',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40993351&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ci',
#    'code': '40993351',
#    'ids': ',ci40993351,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.06043,
#    'rms': 0.19,
#    'gap': 71,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 10 km W of Aguanga, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.9763333, 33.4551667, 5.36]},
#   'id': 'ci40993351'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '63 km N of Petersville, Alaska',
#    'time': 1749834660539,
#    'updated': 1749938119040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0257jibn6h',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0257jibn6h&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'ak',
#    'code': '0257jibn6h',
#    'ids': ',us6000qk4b,ak0257jibn6h,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.51,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 63 km N of Petersville, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.7564, 63.0667, 117.5]},
#   'id': 'ak0257jibn6h'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.16,
#    'place': '4 km NNE of Velma, Oklahoma',
#    'time': 1749834639159,
#    'updated': 1750087879231,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2025lncz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2025lncz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 21,
#    'net': 'ok',
#    'code': '2025lncz',
#    'ids': ',ok2025lncz,',
#    'sources': ',ok,',
#    'types': ',origin,phase-data,',
#    'nst': 50,
#    'dmin': 0.1781650379,
#    'rms': 0.34,
#    'gap': 83,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 4 km NNE of Velma, Oklahoma'},
#   'geometry': {'type': 'Point', 'coordinates': [-97.6575, 34.49616667, 12.84]},
#   'id': 'ok2025lncz'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.15,
#    'place': '15 km ESE of Little Lake, CA',
#    'time': 1749834157060,
#    'updated': 1749842354065,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37730428',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37730428&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'ci',
#    'code': '37730428',
#    'ids': ',ci37730428,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.07509,
#    'rms': 0.06,
#    'gap': 123,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 15 km ESE of Little Lake, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.7451667, 35.9026667, 7.54]},
#   'id': 'ci37730428'},
#  ...]

# %%
# For our Data Factory: Define your variables
output_data = {
    "start_date": start_date,
    "end_date": end_date,
    "bronze_adls": bronze_adls,
    "silver_adls": silver_adls,
    "gold_adls": gold_adls
}

# Serialize the dictionary to a JSON string
output_json = json.dumps(output_data)

# Log the serialized JSON for debugging
print(f"Serialized JSON: {output_json}")

# Return the JSON string
dbutils.notebook.exit(output_json)
